# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"E:\Mobile phone price\Cellphone.csv")

# %%
df.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
df.shape
# Out:
# (161, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %%
df.dtypes
# Out:
# Product_id        int64
# Price             int64
# Sale              int64
# weight          float64
# resoloution     float64
# ppi               int64
# cpu core          int64
# cpu freq        float64
# internal mem    float64
# ram             float64
# RearCam         float64
# Front_Cam       float64
# battery           int64
# thickness       float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# Product_id      0.0
# Price           0.0
# Sale            0.0
# weight          0.0
# resoloution     0.0
# ppi             0.0
# cpu core        0.0
# cpu freq        0.0
# internal mem    0.0
# ram             0.0
# RearCam         0.0
# Front_Cam       0.0
# battery         0.0
# thickness       0.0
# dtype: float64

# %%
df.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# min    121.000000    0.000000    0.000000      0.000000    0.000000
# 25%    233.000000    4.000000    1.200000      8.000000    1.000000
# 50%    294.000000    4.000000    1.400000     16.000000    2.000000
# 75%    428.000000    8.000000    1.875000     32.000000    3.000000
# max    806.000000    8.000000    2.700000    128.000000    6.000000
#
#           RearCam   Front_Cam      battery   thickness
# count  161.000000  161.000000   161.000000  161.000000
# mean    10.378261    4.503106  2842.111801    8.921739
# std      6.181585    4.342053  1366.990838    2.192564
# min      0.000000    0.000000   800.000000    5.100000
# 25%      5.000000    0.000000  2040.000000    7.600000
# 50%     12.000000    5.000000  2800.000000    8.400000
# 75%     16.000000    8.000000  3240.000000    9.800000
# max     23.000000   20.000000  9500.000000   18.500000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr()
# Out:
#                Price    Sale  weight  resoloution     ppi  cpu core  cpu freq  \
# Price         1.0000  0.2733  0.1446       0.4040  0.8176    0.6868    0.7274
# Sale          0.2733  1.0000  0.0161       0.0172  0.2359    0.0695    0.0991
# weight        0.1446  0.0161  1.0000       0.8904 -0.0547    0.2163    0.2227
# resoloution   0.4040  0.0172  0.8904       1.0000  0.1813    0.4722    0.5055
# ppi           0.8176  0.2359 -0.0547       0.1813  1.0000    0.4880    0.7132
# cpu core      0.6868  0.0695  0.2163       0.4722  0.4880    1.0000    0.4915
# cpu freq      0.7274  0.0991  0.2227       0.5055  0.7132    0.4915    1.0000
# internal mem  0.7767  0.4893  0.0988       0.2027  0.6186    0.2763    0.4414
# ram           0.8969  0.3731  0.1493       0.3272  0.7487    0.4831    0.6335
# RearCam       0.7395  0.2922 -0.0294       0.2499  0.7740    0.6114    0.6251
# Front_Cam     0.6753  0.4372 -0.0060       0.2027  0.4914    0.5867    0.3583
# battery       0.5599  0.1203  0.8338       0.8435  0.3025    0.4597    0.4731
# thickness    -0.7168 -0.0480 -0.1853      -0.5337 -0.4968   -0.6979   -0.6145
#
#               internal mem     ram  RearCam  Front_Cam  battery  thickness
# Price               0.7767  0.8969   0.7395     0.6753   0.5599    -0.7168
# Sale                0.4893  0.3731   0.2922     0.4372   0.1203    -0.0480
# weight              0.0988  0.1493  -0.0294    -0.0060   0.8338    -0.1853
# resoloution         0.2027  0.3272   0.2499     0.2027   0.8435    -0.5337
# ppi                 0.6186  0.7487   0.7740     0.4914   0.3025    -0.4968
# cpu core            0.2763  0.4831   0.6114     0.5867   0.4597    -0.6979
# cpu freq            0.4414  0.6335   0.6251     0.3583   0.4731    -0.6145
# internal mem        1.0000  0.8754   0.4519     0.5557   0.4615    -0.3674
# ram                 0.8754  1.0000   0.6481     0.6475   0.5410    -0.5211
# RearCam             0.4519  0.6481   1.0000     0.5964   0.2878    -0.5510
# Front_Cam           0.5557  0.6475   0.5964     1.0000   0.2953    -0.4935
# battery             0.4615  0.5410   0.2878     0.2953   1.0000    -0.4127
# thickness          -0.3674 -0.5211  -0.5510    -0.4935  -0.4127     1.0000

# %%
key_features = ['ram', 'internal mem', 'battery', 'RearCam', 'Front_Cam', 'cpu core', 'Price']
df_key = df[key_features]

plt.figure(figsize=(10, 8))
plt.scatter(df['internal mem'], df['Price'], c=df['ram'], cmap='viridis', alpha=0.6, s=100)
plt.colorbar(label='RAM (GB)')
plt.xlabel('Internal Memory (GB)')
plt.ylabel('Price')
plt.title('Price vs Storage (colored by RAM)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
cols = list(df.columns)
cols.insert(0, cols.pop(cols.index('Price')))
df_clean_ordered = df[cols]
plt.figure(figsize=(10, 8)) 
sns.heatmap(
    df_clean_ordered.corr(), 
    annot=True,       
    cmap='coolwarm',   
    fmt=".2f",         
    linewidths=.5      
)

plt.title("Heatmap of Features", fontsize=16)
plt.xticks(rotation=45, ha='right') 
plt.yticks(rotation=0)
plt.tight_layout() 
plt.show()

# %%
df.nunique()
# Out:
# Product_id       83
# Price            81
# Sale            125
# weight           62
# resoloution      24
# ppi              45
# cpu core          6
# cpu freq         28
# internal mem     10
# ram              12
# RearCam          18
# Front_Cam        15
# battery          55
# thickness        49
# dtype: int64

# %%
df.drop('Product_id', axis=1, inplace=True)

# %%
df = df.rename(columns={"screen_size": "resoloution"})

# %%
df.head(3)
# Out:
#    Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  internal mem  \
# 0   2357    10   135.0          5.2  424         8      1.35          16.0
# 1   1749    10   125.0          4.0  233         2      1.30           4.0
# 2   1916    10   110.0          4.7  312         4      1.20           8.0
#
#    ram  RearCam  Front_Cam  battery  thickness
# 0  3.0    13.00        8.0     2610        7.4
# 1  1.0     3.15        0.0     1700        9.9
# 2  1.5    13.00        5.0     2000        7.6

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Price'], bins=30, kde=True) 
plt.title('Distribution of Mobile Phone Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(6,4)) # fig size means the size of the plot, (width, height)
sns.boxplot(x=df['Price'])
plt.title('Box Plot of Mobile Prices')
plt.show()

# %% [markdown]
# <h1><b>Feature Analysis</h1>

# %%
numerical_features = ['ram', 'internal mem', 'resoloution', 'Front_Cam', 'RearCam', 'battery']

plt.figure(figsize=(15, 10))
for i, feature in enumerate(numerical_features, 1):
    plt.subplot(2, 3, i) 
    plt.scatter(df[feature], df['Price'], alpha=0.5)
    plt.xlabel(feature)
    plt.ylabel('Price')
    plt.title(f'{feature} vs Price')
plt.tight_layout()
plt.show()

# %%
df2= df.copy()
df2['internal mem'] = df2['internal mem'].astype('int64')
df2['ram'] = df2['ram'].astype('int64')
df2['RearCam'] = df2['RearCam'].astype('int64')
df2['Front_Cam'] = df2['Front_Cam'].astype('int64')

print("Data types after conversion:")
print(df2.dtypes)
# Out:
# Data types after conversion:
# Price             int64
# Sale              int64
# weight          float64
# resoloution     float64
# ppi               int64
# cpu core          int64
# cpu freq        float64
# internal mem      int64
# ram               int64
# RearCam           int64
# Front_Cam         int64
# battery           int64
# thickness       float64
# dtype: object

# %% [markdown]
# <h1>Model Training</h1>

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in .\price\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in .\price\Lib\site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in .\price\Lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in .\price\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in .\price\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression

# %%
features = ['weight', 'resoloution', 'ppi', 'cpu core', 'cpu freq', 'internal mem', 'ram', 'RearCam', 'Front_Cam', 'battery', 'thickness']
X = df2[features]
y = df2['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=43)
X_train
# Out:
#      weight  resoloution  ppi  cpu core  cpu freq  internal mem  ram  RearCam  \
# 116   170.0          5.5  401         8     2.000            32    4       12
# 17    168.0          5.5  534         4     1.875            32    4       12
# 92    154.0          5.0  294         4     1.200             8    1       13
# 103   158.0          5.1  432         4     2.500            16    2       16
# 66    158.0          5.5  401         4     1.830            64    4       13
# ..      ...          ...  ...       ...       ...           ...  ...      ...
# 58    131.0          5.0  294         4     1.300            16    2       13
# 21    147.0          5.2  282         8     1.400            32    3       13
# 49    168.0          5.7  386         8     1.800            32    3       21
# 64    168.0          5.7  386         8     1.800            32    3       21
# 68    128.0          4.5  245         4     1.200             4    1        8
#
#      Front_Cam  battery  thickness
# 116         13     5000        8.0
# 17           8     3450        8.5
# 92           5     2100        8.4
# 103          2     2800        8.9
# 66           5     4000        8.5
# ..         ...      ...        ...
# 58           5     2500        8.7
# 21          16     2900        7.7
# 49           5     3050        7.5
# 64           5     3050        7.5
# 68           0     1840        8.5
#
# [128 rows x 11 columns]

# %%
# train the model
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# predict in unseen data
y_pred=model.predict(X_test)

# %%
result=pd.DataFrame({'Actual':y_test,'predicted':y_pred})
result
# Out:
#      Actual    predicted
# 19     1238  1373.463721
# 71     2276  2401.902281
# 39     2392  2664.152198
# 108    1676  1872.061151
# 0      2357  2690.680733
# 101     833   886.171489
# 124    2880  3075.193561
# 37     2124  2220.769720
# 65     2824  2597.241997
# 147    3102  3273.920156
# 94     1511  1577.278560
# 55     1777  1494.762627
# 153    4361  4229.674343
# 10     2438  2877.526242
# 50     1741  1580.987791
# 38     1777  1494.762627
# 45     1989  2068.601752
# 118    2054  2445.534014
# 2      1916  1968.268859
# 11     2006  1972.789760
# 30     2258  2180.879746
# 15     1612  1724.204870
# 12     2174  1911.922279
# 148    3055  3017.901098
# 98     1522  1459.030943
# 79     3005  2993.182457
# 69     2323  2493.961559
# 121    2054  2445.534014
# 106    2744  2577.523145
# 67     2044  2315.447571
# 1      1749  1511.659740
# 115    2858  2755.707189
# 144    1921  1777.177094

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.8989597509072682

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 174.9233216715214

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %%
models = {
    "Lasso": Lasso(alpha=0.01),
    "Decision Tree": DecisionTreeRegressor(random_state=42), 
    "Random Forest": RandomForestRegressor(n_estimators=300, random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=200, 
    learning_rate=0.05,
    max_depth=3,
    subsample=0.8,
    random_state=42)
}

results = []

for name, model in models.items():
    # Fit the model
    model.fit(X_train, y_train)
    
    # Make predictions on BOTH sets
    train_preds = model.predict(X_train)
    test_preds = model.predict(X_test)
    
    # Calculate metrics for BOTH sets
    train_r2 = r2_score(y_train, train_preds)
    test_r2 = r2_score(y_test, test_preds)
    
    train_mae = mean_absolute_error(y_train, train_preds)
    test_mae = mean_absolute_error(y_test, test_preds)
    
    train_mse = mean_squared_error(y_train, train_preds)
    test_mse = mean_squared_error(y_test, test_preds)

    results.append({
        "Model": name,
        "Train R²": train_r2,
        "Test R²": test_r2,
        "Train MAE": train_mae,
        "Test MAE": test_mae,
        "Train MSE": train_mse,
        "Test MSE": test_mse
    })
results_df = pd.DataFrame(results).sort_values(by="Test R²", ascending=False)

pd.set_option('display.float_format', '{:.4f}'.format)
display(results_df)
# Out:
#                Model  Train R²  Test R²  Train MAE  Test MAE  Train MSE  \
# 3  Gradient Boosting    0.9988   0.9442    22.0019   94.8809   732.7578
# 2      Random Forest    0.9943   0.9425    39.1477  116.9242  3597.2825
# 1      Decision Tree    1.0000   0.9225     0.0000   69.7576     0.0000
# 0              Lasso    0.9591   0.8989   128.1614  174.9304 25671.6476
#
#     Test MSE
# 3 23701.8684
# 2 24417.1829
# 1 32942.3636
# 0 42934.8295

# %% [markdown]
# <h1>Feature Analysis</h1>

# %%
best_model = models['Gradient Boosting']
importances = best_model.feature_importances_
feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)
plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Feature Importance for Gradient Boosting', fontsize=16)
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.show()
# Out:
# C:\Users\alian\AppData\Local\Temp\ipykernel_15452\1791831818.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')

# %% [markdown]
# <h1>Creation & Deployment of model</h1>

# %%
#Building and saving the final model for Users

import joblib
import os
from sklearn.ensemble import GradientBoostingRegressor

# --- 1. CREATE AND TRAIN THE FINAL MODEL 
final_model = GradientBoostingRegressor(random_state=42)
print("Training final model on all data...")
final_model.fit(X, y)
print("Training complete.")

# --- 2. SAVE THE MODEL 
# Create a directory to store the model if it doesn't exist
os.makedirs('./models', exist_ok=True)

# Save the trained model to a .pkl file
model_path = './models/model.pkl'
joblib.dump(final_model, model_path)

print(f"✓ Model saved to: {model_path}")
# Out:
# Training final model on all data...
# Training complete.
# ✓ Model saved to: ./models/model.pkl
